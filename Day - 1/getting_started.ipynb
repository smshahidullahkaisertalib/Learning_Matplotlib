# %% [markdown]
# Staring Matplotlib

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %% [markdown]
# PyPlot

# %%
import matplotlib.pyplot as plt
import numpy as np

xp = np.array([0, 1500])
yp = np.array([1, 2000])

plt.plot(xp, yp)
plt.show()
