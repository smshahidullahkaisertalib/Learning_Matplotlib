# %% [markdown]
# Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np
xp = np.array([0,3,5,7,10])
yp = np.array([1,4,6,7,8])

plt.plot(xp, yp)
plt.show()

# %% [markdown]
# plotting with marker

# %%
import matplotlib.pyplot as plt
import numpy as np

# xp = np.array([1,2,4,6,8])
yp = np.array([1,3,5,4,6,4,3,2,6,4,7,3,5,6,9,7])

plt.plot( yp, "o-.",color = "#336600", ms=10, mfc = "#336600")
plt.show()
